# %% [markdown]
# # Training
#
# ## How to learn a network?
# Divergence function: function to quantitatively measure the difference between the reference function g(x) and the output f(x). The formula to compute *ERROR* is called divergence function.
#
# We don't have the whole g(x), but a sampling the function.
